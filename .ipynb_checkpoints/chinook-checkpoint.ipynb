# %% [markdown]
# ### Importing modules

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline

# %% [markdown]
# ### Connecting to db

# %%
conn = sqlite3.connect("chinook.db")

# %%
def run_query(q):
    return pd.read_sql(q, conn)

# %%
def run_command(q):
    conn.cursor().execute(q)

# %% [markdown]
# ### Checking tables inside db

# %%
def show_tables():
    q = "SELECT * FROM sqlite_master WHERE type='table';"
    return run_query(q)

# %%
show_tables()
# Out:
#      type            name        tbl_name  rootpage  \
# 0   table           album           album         2
# 1   table          artist          artist         3
# 2   table        customer        customer         4
# 3   table        employee        employee         5
# 4   table           genre           genre         6
# 5   table         invoice         invoice         7
# 6   table    invoice_line    invoice_line         8
# 7   table      media_type      media_type         9
# 8   table        playlist        playlist        10
# 9   table  playlist_track  playlist_track        11
# 10  table           track           track        13
#
#                                                   sql
# 0   CREATE TABLE [album]\n(\n    [album_id] INTEGE...
# 1   CREATE TABLE [artist]\n(\n    [artist_id] INTE...
# 2   CREATE TABLE [customer]\n(\n    [customer_id] ...
# 3   CREATE TABLE [employee]\n(\n    [employee_id] ...
# 4   CREATE TABLE [genre]\n(\n    [genre_id] INTEGE...
# ...

# %% [markdown]
# <h3 align="left">Here is the tables schema</h3>
# <img src="https://s3.amazonaws.com/dq-content/190/chinook-schema.svg" alt="Scehma image" style="width: 600px; float:left;"/>

# %%
q = '''
WITH total_sold AS (
    SELECT 
        CAST(SUM(il.quantity) AS FLOAT) AS total_qty
    FROM invoice_line AS il
    INNER JOIN invoice AS i ON il.invoice_id = i.invoice_id
    WHERE i.billing_country = "USA"
    )

SELECT
    g.name AS genre,
    SUM(il.quantity) AS tracks_sold_qty,
    SUM(il.quantity) / (SELECT * FROM total_sold) AS tracks_sold_pct
FROM invoice_line AS il
INNER JOIN track AS t ON il.track_id = t.track_id
INNER JOIN genre AS g ON t.genre_id = g.genre_id
INNER JOIN invoice AS i ON il.invoice_id = i.invoice_id
WHERE i.billing_country = "USA"
GROUP BY t.genre_id
ORDER BY 2 DESC
'''
genre_sales_usa = run_query(q)
genre_sales_usa.head(10)
# Out:
#                 genre  tracks_sold_qty  tracks_sold_pct
# 0                Rock              561         0.533777
# 1  Alternative & Punk              130         0.123692
# 2               Metal              124         0.117983
# 3            R&B/Soul               53         0.050428
# 4               Blues               36         0.034253
# 5         Alternative               35         0.033302
# 6               Latin               22         0.020932
# 7                 Pop               22         0.020932
# 8         Hip Hop/Rap               20         0.019029
# 9                Jazz               14         0.013321

# %%
genre_sales_usa = genre_sales_usa.head(10)

# %% [markdown]
# ### Visualizing genres sales in USA

# %%
genre_sales_usa.set_index('genre', inplace=True, drop=True)

# %%
genre_sales_usa['tracks_sold_qty'].plot.barh(
    cmap = plt.cm.Accent)

plt.title('Number of tracks sold per genre in USA')
plt.ylabel('')
plt.gca().invert_yaxis()


for i, v in enumerate(list(genre_sales_usa.index)):
    score = genre_sales_usa.loc[v, "tracks_sold_qty"]
    label = (genre_sales_usa.loc[v, "tracks_sold_pct"] * 100
            ).astype(int).astype(str) + "%"
    plt.annotate(str(label), (score+5, i+0.2))

plt.show()

# %% [markdown]
# Recomendation is to go for following genres from proposed:
# - Punk
# - Blues
# - Pop

# %% [markdown]
# ### Employees sales performance

# %%
q = '''
WITH total_customer_purchase AS
    (SELECT
        customer_id,
        SUM(total) AS total
    FROM invoice
    GROUP BY 1)

SELECT
    e.first_name || " " || e.last_name AS employee_name,
    e.hire_date,
    SUM(tcp.total) AS total_sales    
FROM total_customer_purchase AS tcp
INNER JOIN customer AS c ON tcp.customer_id = c.customer_id
LEFT JOIN employee AS e ON c.support_rep_id = e.employee_id
GROUP BY 1
'''

run_query(q)
# Out:
#    employee_name            hire_date  total_sales
# 0   Jane Peacock  2017-04-01 00:00:00      1731.51
# 1  Margaret Park  2017-05-03 00:00:00      1584.00
# 2  Steve Johnson  2017-10-17 00:00:00      1393.92

# %%
employees_performance = run_query(q)

employees_performance.set_index('employee_name', drop=True, inplace=True)

employees_performance['total_sales'].plot.barh(cmap = plt.cm.Paired)
plt.title('Employees sales performance')
plt.ylabel('')
plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# difference in performance can be explained by level of experience of employees (different date of hire)

# %% [markdown]
# ### Analyzing the sales data for customers from each different country

# %%
q ='''
WITH reviewed_country AS
    (SELECT    
        country,
        CASE 
            WHEN COUNT(customer_id) > 1 THEN country
            ELSE 'Other'
        END AS country2,
        COUNT(customer_id) AS number_of_customers
    FROM customer
    GROUP BY country),
    
            
    invoice2 AS
    (SELECT
        rc.country2,
        i.invoice_id,
        i.customer_id,    
        i.total,
        CASE 
            WHEN country2 = 'Other' THEN 1
            ELSE 0
        END AS sort
    FROM invoice AS i
    LEFT JOIN customer AS c ON i.customer_id = c.customer_id
    LEFT JOIN reviewed_country AS rc ON c.country = rc.country),
    
    
    country_customer AS
    (SELECT 
        country2,
        SUM(number_of_customers) AS number_of_customers
    FROM reviewed_country
    GROUP BY country2),
    
    country_order AS
    (SELECT
        country2,
        COUNT(invoice_id) AS number_of_orders
    FROM invoice2
    GROUP BY country2)
    

SELECT
    i2.country2 AS country,
    cc.number_of_customers AS customers,    
    SUM(i2.total) AS total_sales,
    SUM(i2.total) / co.number_of_orders AS average_order,
    SUM(i2.total) / cc.number_of_customers AS average_value_per_customer

FROM invoice2 AS i2
LEFT JOIN country_customer AS cc ON i2.country2 = cc.country2
LEFT JOIN country_order AS co ON i2.country2 = co.country2
GROUP BY i2.country2
ORDER BY i2.sort ASC, total_sales DESC
'''

run_query(q)
# Out:
#           country  customers  total_sales  average_order  \
# 0             USA         13      1040.49       7.942672
# 1          Canada          8       535.59       7.047237
# 2          Brazil          5       427.68       7.011148
# 3          France          5       389.07       7.781400
# 4         Germany          4       334.62       8.161463
# 5  Czech Republic          2       273.24       9.108000
# 6  United Kingdom          3       245.52       8.768571
# 7        Portugal          2       185.13       6.383793
# 8           India          2       183.15       8.721429
# 9           Other         15      1094.94       7.448571
#
#    average_value_per_customer
# 0                   80.037692
# 1                   66.948750
# 2                   85.536000
# 3                   77.814000
# 4                   83.655000
# 5                  136.620000
# 6                   81.840000
# 7                   92.565000
# 8                   91.575000
# ...

# %%
country_data = run_query(q)

# %%
country_data.set_index('country', drop=True, inplace=True)

# %%
###################################################################
# The code in this cell was written by the guys from Dataquest.io #
###################################################################

country_metrics = country_data.copy()
country_metrics.rename(columns={'average_value_per_customer': 'customer_lifetime_value'}, inplace=True)

colors = [plt.cm.Accent(i) for i in np.linspace(0, 1, country_metrics.shape[0])]

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(11, 12))
ax1, ax2, ax3, ax4 = axes.flatten()
fig.subplots_adjust(hspace=.5, wspace=.3)


# top left
sales_breakdown = country_metrics["total_sales"].copy().rename('')
sales_breakdown.plot.pie(
    ax=ax1,
    startangle=-90,
    counterclock=False,
    title='Sales Breakdown by Country,\nNumber of Customers',
    colormap=plt.cm.Paired,
    fontsize=8,
    wedgeprops={'linewidth':0}
    
)

# top right
cvd_cols = ["customers","total_sales"]
custs_vs_dollars = country_metrics[cvd_cols].copy()
custs_vs_dollars.index.name = ''
for c in cvd_cols:
    custs_vs_dollars[c] /= custs_vs_dollars[c].sum() / 100
    
custs_vs_dollars.plot.bar(
    ax=ax2,
    colormap=plt.cm.Set1,
    title="Pct Customers vs Sales")

ax2.tick_params(top="off", right="off", left="off", bottom="off")
ax2.spines["top"].set_visible(False)
ax2.spines["right"].set_visible(False)


# bottom left
avg_order = country_metrics["average_order"].copy()
avg_order.index.name = ''
difference_from_avg = avg_order * 100 / avg_order.mean() - 100
difference_from_avg.drop("Other", inplace=True)
difference_from_avg.plot.bar(
    ax=ax3,
    color=colors,
    title="Average Order,\nPct Difference from Mean"
)
ax3.tick_params(top="off", right="off", left="off", bottom="off")
ax3.axhline(0, color='k')
ax3.spines["top"].set_visible(False)
ax3.spines["right"].set_visible(False)
ax3.spines["bottom"].set_visible(False)

# bottom right
ltv = country_metrics["customer_lifetime_value"].copy()
ltv.index.name = ''
ltv.drop("Other",inplace=True)
ltv.plot.bar(
    ax=ax4,
    color=colors,
    title="Customer Lifetime Value, Dollars"
)
ax4.tick_params(top="off", right="off", left="off", bottom="off")
ax4.spines["top"].set_visible(False)
ax4.spines["right"].set_visible(False)

plt.show()

# %%
# and here is my attempt
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 12))
ax1, ax2, ax3, ax4 = axes.flatten()
fig.subplots_adjust(wspace=0.7)

#1
total_sales = country_data['total_sales'].copy().rename('')
total_sales.plot.pie(
    ax=ax1,
    startangle=90,
    counterclock=False,
    cmap = plt.cm.Paired,
    title='Total Sales by Country',
    )

#2
customers = country_data['customers'].copy()
customers.index.name = ''
customers[::-1].plot.barh(
    ax=ax2,
    cmap = cm.Paired,
    title='Number of Customers by Country')
ax2.tick_params(top="off", right="off", left="off", bottom="off")
ax2.spines["top"].set_visible(False)
ax2.spines["right"].set_visible(False)


my_colors = cm.Paired(np.linspace(0, 1, country_data.shape[0]))

#3
average_order = country_data['average_order'].copy()
average_order.index.name = ''
average_order[::-1].plot.barh(
    ax = ax3,
    color = my_colors,  #red, green, blue, black, etc.    
    title='Average order in $ by Country')
ax3.tick_params(top="off", right="off", left="off", bottom="off")
ax3.spines["top"].set_visible(False)
ax3.spines["right"].set_visible(False)

#4
average_per_customer = country_data['average_value_per_customer'].copy()
average_per_customer.index.name = ''
average_per_customer.plot(
    kind='bar',
    ax = ax4,
    color = my_colors,
    title='Average value per customer')
ax4.tick_params(top="off", right="off", left="off", bottom="off")
ax4.spines["top"].set_visible(False)
ax4.spines["right"].set_visible(False)

plt.show()

# %% [markdown]
# ### Finding the share of full-album purchases - part 1

# %%
main_query = '''
WITH
    invoice_line_album AS 
        (    
        SELECT 
            il.*,
            t.album_id
        FROM invoice_line AS il
        INNER JOIN track AS t ON il.track_id = t.track_id        
        ),
        
    invoice_full_album AS
        (        
        SELECT 
            ila.invoice_id,            

            CASE
                WHEN
                    (SELECT
                        track_id
                    FROM
                        (SELECT
                            t.album_id,
                            t.track_id
                        FROM track AS t
                        WHERE t.album_id = ila.album_id

                        EXCEPT

                        SELECT 
                            ila2.album_id,
                            ila2.track_id
                        FROM invoice_line_album AS ila2
                        WHERE 
                            ila2.album_id = ila.album_id
                            AND
                            ila2.invoice_id = ila.invoice_id)
                    ) IS NULL THEN 'yes'
                ELSE 'no'        
            END AS 'full_album_purchase'

        FROM invoice_line_album AS ila
        GROUP BY 1, 2
        )
        
SELECT
    full_album_purchase,
    COUNT(invoice_id) AS number_of_invoices,
    CAST(COUNT(invoice_id) AS FLOAT) / (SELECT COUNT(*) FROM invoice_full_album) AS percent 
FROM invoice_full_album
GROUP BY 1

'''
run_query(main_query)
# Out:
#   full_album_purchase  number_of_invoices   percent
# 0                  no                 500  0.713267
# 1                 yes                 201  0.286733

# %% [markdown]
# the approach is based on the fact that in one invoice a customer can buy some random tracks + a full album.
# the common case of this is when an album consists of only 1 track and this track is present in the invoice among others.
#
# e.g. invoice 7 with track 3439 from album 305.

# %%
invoices = '''
SELECT il.*, t.album_id
FROM invoice_line AS il
INNER JOIN track AS t ON il.track_id = t.track_id
WHERE invoice_id = 7
''' 

run_query(invoices)
# Out:
#     invoice_line_id  invoice_id  track_id  unit_price  quantity  album_id
# 0                56           7      3477        0.99         1       322
# 1                57           7      3439        0.99         1       305
# 2                58           7      1102        0.99         1        87
# 3                59           7       711        0.99         1        55
# 4                60           7      1988        0.99         1       163
# 5                61           7      3024        0.99         1       239
# 6                62           7       834        0.99         1        67
# 7                63           7      2596        0.99         1       211
# 8                64           7      1343        0.99         1       106
# 9                65           7      2644        0.99         1       214
# 10               66           7        42        0.99         1         6

# %% [markdown]
# and the album 305 in its turn consists only of 1 track

# %%
full_album = '''
SELECT * FROM track
WHERE album_id = 305
'''

run_query(full_album)
# Out:
#    track_id                                   name  album_id  media_type_id  \
# 0      3439  Das Lied Von Der Erde, Von Der Jugend       305              2
#
#    genre_id       composer  milliseconds    bytes  unit_price
# 0        24  Gustav Mahler        223583  3700206        0.99

# %% [markdown]
# actually there are plenty of albums like this in the db

# %%
album_one_track = '''
SELECT
    album_id,
    COUNT(track_id) AS number_of_tracks
FROM track
GROUP BY album_id
ORDER BY 2, 1
'''
run_query(album_one_track)['number_of_tracks'].value_counts().plot.bar() 
plt.title('Albums by number of tracks')
plt.xlabel('number of tracks per album')
plt.ylabel('number of albums')
plt.show()

# %%
number_of_albums = '''
SELECT
    COUNT(DISTINCT album_id)
    FROM track
'''
run_query(number_of_albums)
# Out:
#    COUNT(DISTINCT album_id)
# 0                       347

# %%
number_of_tracks = '''
SELECT
    COUNT(DISTINCT track_id)
    FROM track
'''
run_query(number_of_tracks)
# Out:
#    COUNT(DISTINCT track_id)
# 0                      3503

# %% [markdown]
# ### Finding the share of full-album purchases - part 2

# %%
draft_query = '''
WITH
    invoice_line_album AS 
        (    
        SELECT 
            il.*,
            t.album_id,
            i.customer_id
        FROM invoice_line AS il
        INNER JOIN track AS t ON il.track_id = t.track_id
        INNER JOIN invoice AS i ON il.invoice_id = i.invoice_id
        )        
    
SELECT 
    ila.customer_id,
    ila.invoice_id,   
    ila.album_id,
    ila.track_id,

    CASE
        WHEN
            (SELECT
                track_id
            FROM
                (SELECT
                    t.album_id,
                    t.track_id
                FROM track AS t
                WHERE t.album_id = ila.album_id

                EXCEPT

                SELECT 
                    ila2.album_id,
                    ila2.track_id
                FROM invoice_line_album AS ila2
                WHERE 
                    ila2.album_id = ila.album_id
                    AND
                    ila2.invoice_id <= ila.invoice_id
                    AND
                    ila2.customer_id = ila.customer_id)
            ) IS NULL THEN 'yes'
        ELSE 'no'        
    END AS 'full_album_purchase'

FROM invoice_line_album AS ila
ORDER BY 1, 2
'''
run_query(draft_query).head(20)
# Out:
#     customer_id  invoice_id  album_id  track_id full_album_purchase
# 0             1          16       178      2160                  no
# 1             1          16        70       875                  no
# 2             1          16         9        83                  no
# 3             1          16         4        16                  no
# 4             1          16       145      1756                  no
# 5             1          16       321      3460                  no
# 6             1          16        10        93                  no
# 7             1          16         5        24                  no
# 8             1          16         4        21                  no
# 9             1          77         4        15                 yes
# 10            1          77         4        17                 yes
# 11            1          77         4        18                 yes
# 12            1          77         4        19                 yes
# ...

# %% [markdown]
# This was a draft detailed query.
# Normally it's OK. We can check for example how customer 21 was buying album 1 (don't ask how I picked these numbers...)

# %%
test_data = run_query(draft_query)
test_data.loc[(test_data['customer_id'] == 21) &
             (test_data['album_id'] == 1)]
# Out:
#       customer_id  invoice_id  album_id  track_id full_album_purchase
# 1681           21         322         1        13                  no
# 1694           21         423         1         7                  no
# 1702           21         496         1         1                 yes
# 1703           21         496         1         6                 yes
# 1704           21         496         1         8                 yes
# 1705           21         496         1         9                 yes
# 1706           21         496         1        10                 yes
# 1707           21         496         1        11                 yes
# 1708           21         496         1        12                 yes
# 1709           21         496         1        14                 yes

# %% [markdown]
# so we see that at first customer buys 2 tracks in 2 invoices (lines get 'no').
# then last invoice 496 makes it till full album and gets 'yes'.
#
# we can check the contents of the album 1 below.

# %%
full_album = '''
SELECT * FROM track
WHERE album_id = 1
'''

run_query(full_album)
# Out:
#    track_id                                     name  album_id  media_type_id  \
# 0         1  For Those About To Rock (We Salute You)         1              1
# 1         6                    Put The Finger On You         1              1
# 2         7                          Let's Get It Up         1              1
# 3         8                         Inject The Venom         1              1
# 4         9                               Snowballed         1              1
# 5        10                               Evil Walks         1              1
# 6        11                                   C.O.D.         1              1
# 7        12                       Breaking The Rules         1              1
# 8        13                 Night Of The Long Knives         1              1
# 9        14                               Spellbound         1              1
#
#    genre_id                                   composer  milliseconds  \
# ...

# %% [markdown]
# so let's combine everything together now

# %%
main_query2= '''
WITH
    invoice_line_album AS 
        (    
        SELECT 
            il.*,
            t.album_id,
            i.customer_id
        FROM invoice_line AS il
        INNER JOIN track AS t ON il.track_id = t.track_id
        INNER JOIN invoice AS i ON il.invoice_id = i.invoice_id
        ),
        
    invoice_full_album AS
        (
        SELECT     
            ila.invoice_id,   

            CASE
                WHEN
                    (SELECT
                        track_id
                    FROM
                        (SELECT
                            t.album_id,
                            t.track_id
                        FROM track AS t
                        WHERE t.album_id = ila.album_id

                        EXCEPT

                        SELECT 
                            ila2.album_id,
                            ila2.track_id
                        FROM invoice_line_album AS ila2
                        WHERE 
                            ila2.album_id = ila.album_id
                            AND
                            ila2.invoice_id <= ila.invoice_id
                            AND
                            ila2.customer_id = ila.customer_id)
                    ) IS NULL THEN 'yes'
                ELSE 'no'        
            END AS 'full_album_purchase'

        FROM invoice_line_album AS ila
        GROUP BY ila.invoice_id, full_album_purchase
        )

SELECT
    full_album_purchase,
    COUNT(invoice_id) AS number_of_invoices,
    CAST(COUNT(invoice_id) AS FLOAT) / (SELECT COUNT(*) FROM invoice_full_album) AS percent 
FROM invoice_full_album
GROUP BY 1

'''

run_query(main_query2)
# Out:
#   full_album_purchase  number_of_invoices   percent
# 0                  no                 478  0.681883
# 1                 yes                 223  0.318117

# %% [markdown]
# So the conclusion is that in ~32% of cases the customers are willing to purchase a full album

# %% [markdown]
# ### The end

# %%
conn.close()
